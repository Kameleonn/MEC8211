# %% [markdown]
# # Testing for notebook integration for this homework

# %% [markdown]
# Testing latex integration with jupyter
#
# $c = \sqrt{a^2 + b^2}$

# %% [markdown]
# nouveau test, collaboration
# Test test test
